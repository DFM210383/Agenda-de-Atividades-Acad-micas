# %% [markdown]
# <a href="https://colab.research.google.com/github/DFM210383/Agenda-de-Atividades-Acad-micas/blob/main/Fundamentos%20Python_Entrada_Processamento_Saida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **EXIBINDO DADOS PARA O USUÁRIO**

# %%
print("Olá, mundo")
# Out:
# Olá, mundo

# %% [markdown]
# A palavra **print** que você pode ver aqui é um nome de
# **função**
#
# Uma função (nesse contexto) é uma parte separada do código do computador capaz de:
#
# *  **causar algum efeito** (por exemplo, envie texto para o terminal, crie um arquivo, desenhe uma imagem, toque um som etc.)
# * **  avaliar um valor** (por exemplo, a raiz quadrada de um valor ou o comprimento de um determinado texto)
# *  e **retorná-lo como resultado da função**; é isso que torna as funções do Python parentes de conceitos matemáticos.
#
#
# https://docs.python.org/3/library/functions.html#print
#
#
# https://docs.python.org/3.11/?authuser=1

# %%
# USO DO '\n' para quebrar a linha

print("Só sei que \n nada sei")
# Out:
# Só sei que
#  nada sei

# %%
# USO DO ARGUMENTO 'END' PARA MUDAR O COMPORTAMENTO DA FUNÇÃO
print("Veni", end=" ")
print("Vidi")
print("Vici")
# Out:
# Veni Vidi
# Vici

# %%
# USO SO ARGUMENTO "SEP" PARA COLCOAR UM DELIMITAR ENTRE AS PALAVRAS
print("Veni", "Vidi", "Vici", sep="-", end="*")
print("Só sei que nada sei")
# Out:
# Veni-Vidi-Vici*Só sei que nada sei

# %% [markdown]
#  **Formas diferentes de exibir dados com o print**

# %%
# 1. SEPARANDO OS TERMOS POR VÍRGULA (,)

nome = "Willian"
idade = 30
cidade = "carapicuíba"

print("Meu nome é", nome, "tenho", idade,"anos e moro em",cidade)
# Out:
# Meu nome é Willian tenho 29 anos e moro em carapicuíba

# %%
# 2. USANDO A FUNÇÃO FORMAT()

print("Meu nome é {} tenho {} anos e moro em {}".format(nome,idade, cidade))
print("Meu nome é {0} tenho {1} anos e moro em {2}". format(nome, idade, cidade))
print("Meu nome é {n} tenho {i} anos e moro em {c}".format(n=nome,i=idade,c=cidade))
# Out:
# Meu nome é Willian tenho 29 anos e moro em carapicuíba
# Meu nome é Willian tenho 29 anos e moro em carapicuíba
# Meu nome é Willian tenho 29 anos e moro em carapicuíba

# %%
# 3.UTILIZANDO O PRINT(f)

print(f"Meu nome é {nome} tenho{idade} e moro em {cidade}")
# Out:
# Meu nome é Willian tenho29 e moro em carapicuíba

# %%
# CURIOSIDADE: EXIBINDO AS CASAS DECIMAIS

peso = 80.52
print(f"O peso é: {peso:.1f}")
# Out:
# O peso é: 80.5

# %% [markdown]
# # **Operações com Variáveis numéricas**

# %% [markdown]
# Um operador é um símbolo da linguagem de programação, capaz de operar com os valores.
#
# Nem todos os operadores Python são tão óbvios quanto o sinal de mais, então vamos ver alguns dos operadores disponíveis no Python, e vamos explicar quais regras regem o uso e como interpretar as operações que realizam.
#
# https://pense-python.caravela.club/02-variaveis-expressoes-e-instrucoes/05-ordem-das-operacoes.html

# %%
# ADIÇÃO

print(-4 + 4)
print(-4. + 8)
# Out:
# 0
# 4.0

# %%
# SUBTRAÇÃO

print(-4 - 4)
print(4. - 8)
print(-1.1)

# %%
# MULTIPLICAÇÃO

print(2 * 3)
print(2 * 3.)
print(2. * 3)
print(2. * 3.)
# Out:
# 6
# 6.0
# 6.0
# 6.0

# %%
# DIVISÃO

print(14 / 3)
print(6 / 3.)
print(6. / 3)
print(6. / 3.)
# Out:
# 4.666666666666667
# 2.0
# 2.0
# 2.0

# %%
# DIVISÃO DE NÚMERO INTEIRO (DIVISÃO ARRENDODADA)

print(14 // 3)
print(6 // 3.)
print(6. // 3)
print(6. // 3.)
# Out:
# 4
# 2.0
# 2.0
# 2.0

# %%
# MÓDULO (RESTO DA DIVISÃO)

print(14 % 4)
# Out:
# 2

# %%
# EXPONENCIAÇÃO

print(2 ** 3)
print(2 ** 3.)
print(2. ** 3)
print(2. ** 3.)
# Out:
# 8
# 8.0
# 8.0
# 8.0

# %% [markdown]
# **EXERCÍCIOS: Inicialize o interpretador do Python e use-o como uma calculadora**
#
# Quantos segundos há em 42 minutos e 42 segundos?
#
# Quantas milhas há em 10 quilômetros? Dica: uma milha equivale a 1,61 quilômetro.

# %% [markdown]
# # **Recebendo dados em variáveis**

# %% [markdown]
# A instrução primitiva de Entrada de Dados é um complemento da instrução de Saída de Dados. Entrada de dados é a instrução que faz a interação do usuário com o algoritmo.
#
# Na saída de dados utilizamos a tela do munitor como referência, na entrada de dados utilizaremos o teclado.

# %%
# Pede a digitação do salário ao usuário
salario = input("Digite o salário:")
salario = float(salario)

# Exibe o salário digitado
print("Salário = R$", salario)

# %% [markdown]
# **EXEMPLO 2:** Faça um programa que peça dois números inteiros. Imprima a soma desses dois números na tela

# %%
num1 = float(input("Digite um número: "))
num2 = float(input("Digite mais um número: "))

soma = num1+num2

print("Soma = ",soma)
# Out:
# Digite um número: 10
# Digite mais um número: 5
# Soma =  15.0

# %% [markdown]
# # **EXERCÍCIOS**

# %% [markdown]
# **EXERCÍCIO 1:** Faça um programa em Python que solicita ao usuário que insira um número inteiro. Em seguida, seu programa deve exiber o antecessor e o sucessor desse número.
#
# Exemplo: "O antecessor do número 10 é 9, e o sucessor é 11"

# %%
numero = int(input('Informe um número inteiro qualquer: '))
print(f'O antecessor do número {numero} é {numero - 1}, e o sucessor é {numero + 1}')
# Out:
# Informe um número inteiro qualquer: 10
# O antecessor do número 10 é 9, e o sucessor é 11

# %% [markdown]
# **EXERCÍCIO 2**: Escreva um programa que leia um valor em metros e o exiba convertido em milímetros

# %%
metros = float(input("Digite o valor em métros: "))
milímetros = metros * 1000
print("%10.3f metros equivalem a %10.3f milímetros." % (metros, milímetros))
# Out:
# Digite o valor em métros: 5
#      5.000 metros equivalem a   5000.000 milímetros.

# %% [markdown]
# **EXERCÍCIO 3:** Dados 4 números pelo usuário, fazer um algoritimo que calcule a média simples destes números

# %%
# Solicitar ao usuário para inserir quatro números
num1 = float(input("Insira o primeiro número: "))
num2 = float(input("Insira o segundo número: "))
num3 = float(input("Insira o terceiro número: "))
num4 = float(input("Insira o quarto número: "))

# Calcular a média simples
media_simples = (num1 + num2 + num3 + num4) / 4

# Exibir a média
print(f"A média simples dos quatro números é: {media_simples}")
# Out:
# Insira o primeiro número: 8
# Insira o segundo número: 7
# Insira o terceiro número: 4
# Insira o quarto número: 8
# A média simples dos quatro números é: 6.75

# %% [markdown]
# **EXERCÍCIO 4**: Dado o **preço do maço de cigarros**, a **quantidade** de maços consumidos por dia e o tempo em **anos** que a pessoa fuma, calcular quanto esta pessoa já gastou fumando.

# %%
# Solicitando os dado ao usuário

preco_maco = float(input("Digite o preço do maço: "))
qtd_maco = float(input("Digite a quantidade de maços: "))
anos = float(input("Digite a qtd. de anos que fuma: "))

# calcula  qtd. de dias como fumante
dias_fumante = anos*365

#calcula o gasto do tempo que fuma
custo = dias_fumante *preco_maco

#exibe ocusto
print("Você já gastou R$ ", custo, "fumando")
# Out:
# Digite o preço do maço: 3.50
# Digite a quantidade de maços: 2
# Digite a qtd. de anos que fuma: 10
# Você já gastou R$  12775.0 fumando

# %% [markdown]
# **EXERCÍCIO 5:** Escreva um programa que leia a quantidade de dias, horas, minutos e segundos do usuário. Calcule o total em segundos

# %%
dias = int(input("Dias:"))
horas = int(input("Horas:"))
minutos = int(input("Minutos:"))
segundos = int(input("Segundos:"))
# Um minuto tem 60 segundos
# Uma hora tem 3600 (60 * 60) segundos
# Um dia tem 24 horas, logo 24 * 3600 segundos
total_em_segundos = dias * 24 * 3600 + horas * 3600 + minutos * 60 + segundos
print("Convertido em segundos é igual a %10d segundos." % total_em_segundos)

# %% [markdown]
# **EXERCÍCIO 6:** Faça um programa que calcule o aumento de um salário. Ele deve solicitar o valor do salário e a porcentagem do aumento. Exiba o valor do aumento e do novo salário.

# %%
salário = float(input("Digite o salário atual:"))
p_aumento = float(input("Digite a porcentagem de aumento:"))
aumento = salário * p_aumento / 100
novo_salário = salário + aumento
print("Um aumento de %5.2f %% em um salário de R$ %7.2f" % (p_aumento, salário))
print("é igual a um aumento de R$ %7.2f" % aumento)
print("Resultando em um novo salário de R$ %7.2f" % novo_salário)
# Out:
# Digite o salário atual:100
# Digite a porcentagem de aumento:5
# Um aumento de  5.00 % em um salário de R$  100.00
# é igual a um aumento de R$    5.00
# Resultando em um novo salário de R$  105.00

# %% [markdown]
# **EXERCÍCIO 7:**Faça um programa que solicite o preço de uma mercadoria e o percentual de desconto. Exiba o valor do desconto e o preço a pagar

# %%
preço = float(input("Digite o preço da mercadoria:"))
desconto = float(input("Digite o percentual de desconto:"))
valor_do_desconto = preço * desconto / 100
a_pagar = preço - valor_do_desconto
print("Um desconto de %5.2f %% em uma mercadoria de R$ %7.2f" % (desconto, preço))
print("vale R$ %7.2f." % valor_do_desconto)
print("O valor a pagar é de R$ %7.2f" % a_pagar)

# %% [markdown]
# **EXERCÍCIO 8:** Elabore um programa em Python que:
# 1. Receba o valor unitário do produto. Lembre-se que número decimal é feito com ponto e não vírgula;
# 2. Receba a a quantidade desse produto;
# 3. O programa deve retornar o valor total sem desconto;
#
#
# DESAFIO: O USUÁRIO DEVE DIGITAR O VALOR NO PADRÃO BRASILEIRO(EX: 3,55) E O PROGRAMA DEVE FAZER AUTOMATICAMENTE A SUBSTITUIÇÃO POR PONTO (EX:3.55). DICA: USE A FUNÇÃO REPLACE().

# %%
preco_unitario = float(input("Digite o preço unitário: ").replace(",","."))
quantidade = int(input("Digite a quantidade: "))

total_sem_desconto = preco_unitario*quantidade

resultado = '{:.2f}'.format(total_sem_desconto).replace(".",",")
print ("Valor total: R$",resultado)

# %% [markdown]
# **EXERCÍCIO 9:** Escrever um programa em Python que peça ao usuário as medidas do cateto a e cateto b. Com essas informações, calcule o perímetro do triângulo retângulo (dado por cateto a + cateto b + hipotenusa) e a área do triângulo (calculada com (cateto a * cateto b) / 2).

# %%
ca = float(input("Digite o valor do cateto A: ").replace(",","."))
cb = float(input("Digite o valor do cateto B: ").replace(",","."))

ca2 = ca**2
cb2 = cb**2
h = (ca2 + cb2)**0.5

perimetro = ca+cb+h
print ("O perímetro do triângulo retângulo é: ",perimetro)

area = (ca*cb)/2
print ("A área do triângulo retângulo é: ",area)
# Out:
# Digite o valor da massa: 3
# 270.000.000.000.000.000

# %% [markdown]
# **EXERCÍCIO 10:** Escreva um programa que pergunte a quantidade de km percorridos por um carro alugado pelo usuário, assim como a quantidade de dias pelos quais o carro foi alugado. Calcule o preço a pagar, sabendo que o carro custa 6O REAIS por dia e  0,15 REAIS por km rodado.

# %%
km = int(input("Digite a quantidade de quilometros percorridos:"))
dias = int(input("Digite quantos dias você ficou com o carro:"))

preço_por_dia = 60
preço_por_km = 0.15

preço_a_pagar = km * preço_por_km + dias * preço_por_dia

print(f"Total a pagar: R$ {preço_a_pagar:.2f}")
# Out:
# Digite a quantidade de quilometros percorridos:1
# Digite quantos dias você ficou com o carro:1
# Total a pagar: R$ 60.15

# %% [markdown]
# **DESAFIO:** Você com certeza já ouviu dizer que E = mc², onde E representa a energia (em Joules), m representa a massa (em quilogramas) e c representa a velocidade da luz (aproximadamente 300.000.000 m/s), essa fórmula foi descoberta por Albert Einstein e significa, em resumo, que massa e energia são equivalentes.
#
# Crie um arquivo chamado einstein.py e escreva um programa em Python que use a massa indicada pelo usuário para calcular o valor equivalente em Joules de energia. Utilizar números inteiros e considerar que o usuário somente irá digitar números válidos.
#
# Fique à vontade para utilizar as funções existentes do Python no link anexo da biblioteca, se precisar.
#
# Exemplo:
#
# Entrada:
# m: 1
# Saída:
# E: 90000000000000000
#
# DESAFIO 1:
#
# Imprimir o resultado com o separador de milhar, exemplo:
# E: 90,000,000,000,000,000
#
# DESAFIO 2:
#
# Trocar o separador de milhar de vírgula ( , ) para ponto ( . ), exemplo:
# E:  90.000.000.000.000.000

# %%
m = int(input("Digite o valor da massa: "))
c = 300000000
e = m*(c*c)


print(f"{e:,f}".replace(",","."))


#resultado = '{0:,}'.format(e).replace(',','.')
#print(resultado)
# Out:
# Digite o valor da massa: 1
# 90.000.000.000.000.000.000000
